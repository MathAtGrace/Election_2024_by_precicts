# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import re
from itertools import batched
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[78], line 5
#       3 import pandas as pd
#       4 import re
# ----> 5 from itertools import batched
#
# ImportError: cannot import name 'batched' from 'itertools' (unknown location)

# %%
pip install
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 itertools
#
# NameError: name 'itertools' is not defined

# %%
county = "Lake"
output_file = "../data/in_2024_results/" + county + ".csv"
output_file
# Out:
# '../data/in_2024_results/Lake.csv'

# %% [markdown]
# Lake County lits results on separate webpages with urls all the same except for an abbreviated name for each precients.  We copied and pasted these abreviated names from the main webpage, then we use the code below to get all of the urls:

# %%
#This cell might only work for Lake County
precints = ["CAL-05", "CAL-06", "CAL-10", "CAL-12", "CAL-14", "CCT-01", "CCT-02", "CCT-04", "CCT-05", "CCT-06", "CCT-07", "CCT-08", "CCT-09", "CL-01", "CL-02", "CL-03", "CL-04", "CL-05", "CL-06", "CL-07", "CL-08", "CL-09", "CL-10", "CP-02", "CP-04", "CP-05", "CP-06", "CP-07", "CP-09", "CP-10", "CP-11", "CP-12", "CP-13", "CP-14", "CP-15", "CP-18", "CP-19", "CP-20", "CP-21", "CP-24", "CP-25", "CP-26", "CP-29", "CP-30", "CP-31", "CP-32", "CT-03", "CT-04", "CT-05", "CT-06", "D-01", "D-02", "D-03", "D-04", "D-05", "D-06", "D-07", "D-08", "D-09", "D-10", "D-11", "D-14", "EC-02", "EC-03", "EC-05", "EC-07", "EC-08", "EC-11", "EC-13", "EC-17", "EC-22", "EC-23", "EC-24", "EC-25", "EC-28", "EC-31", "EC-33", "EC-35", "EC-36", "ECT-01", "ECT-02", "G1-03", "G1-08", "G1-16", "G1-18", "G1-20", "G1-22", "G1-24", "G2-01", "G2-03", "G2-04", "G2-10", "G2-11", "G2-12", "G2-17", "G2-20", "G3-03", "G3-11", "G3-15", "G3-16", "G3-17", "G3-19", "G3-21", "G3-26", "G4-01", "G4-03", "G4-05", "G4-10", "G4-14", "G4-16", "G4-23", "G4-25", "G5-01", "G5-02", "G5-04", "G5-06", "G5-13", "G5-14", "G5-16", "G5-20", "G5-22", "G5-28", "G6-02", "G6-05", "G6-07", "G6-10", "G6-12", "G6-14", "G6-16", "G6-18", "GR-01", "GR-02", "GR-03", "GR-05", "GR-06", "GR-07", "GR-09", "GR-10", "GR-11", "GR-12", "GR-15", "GR-16", "GR-17", "H1-01", "H1-03", "H1-05", "H1-07", "H1-08", "H1-10", "H1-12", "H1-16", "H2-03", "H2-05", "H2-06", "H2-11", "H2-12", "H2-14", "H3-03", "H3-04", "H3-05", "H3-07", "H3-09", "H3-11", "H3-16", "H4-05", "H4-06", "H4-07", "H4-09", "H4-11", "H4-12", "H4-14", "H4-18", "H5-04", "H5-08", "H5-12", "H5-13", "H5-14", "H5-15", "H5-17", "H6-04", "H6-05", "H6-07", "H6-08", "H6-09", "H6-10", "H6-12", "H6-13", "H6-15", "HL-03", "HL-04", "HL-05", "HL-06", "HL-08", "HL-09", "HL-10", "HL-11", "HL-12", "HL-15", "HL-16", "HL-19", "HL-20", "HL-23", "HL-24", "HL-25", "HL-26", "HO-02", "HO-03", "HO-04", "HO-05", "HO-06", "HO-07", "HO-10", "HO-11", "HO-12", "HO-15", "HO-16", "HO-19", "HO-21", "HO-22", "HO-23", "HO-25", "HO-27", "HO-29", "HOT-05", "HOT-08-", "HOT-09", "HT-01", "HT-02", "HT-03", "LS-01", "LS-02", "LS-03", "LS-04", "LS-05", "LS-06", "LS-07", "LS-08", "LS-09", "LS-11", "LS-13", "M-01", "M-02", "M-04", "M-05-", "M-06", "M-08", "M-09", "M-11", "M-12", "M-13", "M-14", "M-15", "M-16", "M-18", "M-19", "M-20", "M-21", "M-22", "M-24", "M-25", "MER-01", "MER-02", "MER-03", "MER-04", "MER-05", "MER-07", "MER-08", "MER-09", "MER-10", "MER-11", "MER-12", "MER-13", "MER-15", "MER-16", "MER-18", "MER-19", "MER-21", "MER-22", "MER-23", "MER-28", "MER-29", "MER-30", "MER-33", "MER-34", "RT-20", "SCH-02", "SCH-04", "SCH-06", "SCH-07", "SCH-09", "SCH-10", "SCH-13", "SCH-14", "SCH-15", "SCH-16", "SCH-17", "SCH-18", "SCH-19-", "SCH-20", "SCH-22", "SCH-24", "SCH-26", "SCH-27", "SCH-28", "SCH-32", "SCH-33", "SJ-01", "SJ-02", "SJ-03", "SJ-04", "SJ-05", "SJ-06", "SJ-07", "SJ-08", "SJ-09", "SJ-10", "SJ-11", "SJ-12", "SJ-13", "SJ-14", "SJ-15", "SJ-16", "SJ-17", "SJ-18", "SJ-19", "SJT-01", "SJT-02", "SJT-03", "SJT-04", "SJT-07", "SJT-08", "SJT-09", "W-01", "W-03", "W-04", "WCT-01", "WCT-02", "WCT-03", "WCT-04", "WCT-06", "WT-01", "WT-02", "WT-05", "WT-06", "WT-07", "WT-08", "WT-09", "WT-10"]
urls = []
for i,p in enumerate(precints):
    urls.append('https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_' +
                '%03d' % (i+1) +
                '-' +
                p +
               '.htm')
urls[:4] + urls[-2:]
# Out:
# ['https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_001-CAL-05.htm',
#  'https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_002-CAL-06.htm',
#  'https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_003-CAL-10.htm',
#  'https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_004-CAL-12.htm',
#  'https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_347-WT-09.htm',
#  'https://lakecountyin.gov/departments/voters/election-results-c/2024GeneralElectionResults/Lake_PrecSumm_348-WT-10.htm']

# %%
lines = []
for url in urls:
    req = Request(url)
    html_page = urlopen(req).read()
    soup = BeautifulSoup(html_page, 'html.parser')
    lines += [s.get_text().strip().replace('\n',' ') for s in soup.find_all('div')]

# %%
lines[100:150]
# Out:
# ['30 3 32 65 27.78% No',
#  '',
#  'VOTE FOR 1',
#  'VOTES= 241 Lake Superior Court Civil Div Room 6',
#  '92 10 73 175 72.61% Yes',
#  '32 2 32 66 27.39% No',
#  '',
#  'Straight Party Votes Precinct ID: 001 PartyName Votes Democratic Party 124 Republican Party 104',
#  'Precinct Summary Report 11/15/2024 - 9:41:27 AM 2024 General Election [Election Date: 11/5/2024] Page 1 of 1',
#  'Precinct Summary Report 11/15/2024 - 9:41:34 AM  Election Date: 11/5/2024 EMS \xa0 Lake County, Indiana 2024 General Election INLAKG24 11/5/2024 \xa0 E - # Of Election Day 300 PRECINCT STATUS: REPORTED A - # Of Paper Absentee 23 W - # Of Walk-In Absentee 147 \xa0PUBLIC COUNT: 470 \xa0VOTER TURNOUT: 56.22% \xa0REGISTERED VOTERS: 836',
#  '002-CAL 06 - - - - - - - - - - - - - - - - - - VOTES - - - - - - - - - - - - - - - - \xa0 \xa0 E A W TOTAL %',
#  'VOTE FOR 1',
#  'VOTES= 382 Public Question-Const Amendment',
#  '145 4 77 226 59.16% Yes',
#  '100 11 45 156 40.84% No',
#  '',
#  'VOTE FOR 1',
#  'VOTES= 466 President and Vice-President of the U.S.',
#  '81 13 52 146 31.33% (D) Harris \\ Walz',
#  '210 10 93 313 67.17% (R) Trump \\ Vance',
#  '2 0 0 2 0.43% (L) Oliver \\ Ter Maat',
#  '1 0 1 2 0.43% (WTP) Kennedy Jr \\ Shanahan',
#  '3 0 0 3 0.64% Write-In',
#  '',
#  'VOTE FOR 1',
#  'VOTES= 443 United States Senator',
#  '87 13 50 150 33.86% (D) Valerie McCray',
#  '191 8 85 284 64.11% (R) Jim Banks',
#  '8 0 1 9 2.03% (L) Andrew Horning',
#  '0 0 0 0 0.00% Write-In',
#  '',
#  'VOTE FOR 1',
#  'VOTES= 444 Governor And Lieutenant Governor',
#  '96 13 51 160 36.04% (D) Mccormick \\ Goodin',
#  '178 8 86 272 61.26% (R) Braun \\ Beckwith',
#  '11 0 1 12 2.70% (L) Rainwater \\ Hudson',
#  '0 0 0 0 0.00% Write-In',
#  '',
#  'VOTE FOR 1',
#  'VOTES= 446 Attorney General',
#  '92 13 50 155 34.75% (D) Destiny Wells',
#  '197 8 86 291 65.25% (R) Todd Rokita',
#  '',
#  'VOTE FOR 1',
#  'VOTES= 454 U.S. Representative District 1',
#  '99 13 54 166 36.56% (D) Frank J Mrvan',
#  '190 7 86 283 62.33% (R) Randy Niemeyer',
#  '4 1 0 5 1.10% (L) Dakotah Miskus',
#  '0 0 0 0 0.00% Write-In',
#  '']

# %%
line = lines[107]
print(line)
print(re.split(r"\s*(\d+)\s*",re.findall(r'PartyName Votes (.*)', line)[0]))
#re.findall(r'(\w+-\w+ \w+) - - -', line)[0]
# Out:
# Straight Party Votes Precinct ID: 001 PartyName Votes Democratic Party 124 Republican Party 104
# ['Democratic Party', '124', 'Republican Party', '104', '']

# %%
cols = {'Precinct_ID' : [],
        'Precinct_Name' : [],
        'Registered_voters' : [],
        'Vote_on' : [],
        'Voter_subset' : [],
        'Vote_option' : [],
        'Vote_num' : []}
df = pd.DataFrame(data=cols)

# %%
cols = {'county' : [],
        'precinct' : [],
        'office' : [],
        'district' : [],
        'party' : [],
        'candidate' : [],
        'election_day' : [],
        'absentee' : [],
        'early_voting' : [],
        'votes' : []}
party_convert = {'R' : 'REP',
                 'REP' : 'REP',
                 'D' : 'DEM',
                 'DEM' : 'DEM',
                 'L' : 'LIB',
                 'LIB' : 'LIB',
                 'WTP' : 'WTP',
                 'W' : 'WTP',
                 'NP' : ''
                }

# %%
vote = False #Signifies when a "VOTE FOR ..." line has occurred
for line in lines: #for each line of the page
    if re.search(' EMS ', line):
        election_day = re.findall(r'# Of Election Day (\d+)', line)[0]
        absentee = re.findall(r'# Of Paper Absentee (\d+)', line)[0]
        early_voting = re.findall(r'# Of Walk-In Absentee (\d+)', line)[0]
        votes = re.findall(r'PUBLIC COUNT: (\d+)', line)[0]
        registered = re.findall(r'REGISTERED VOTERS: (\d+)', line)[0]
        meta = True
    elif re.search('- - -', line):
        precinct = re.findall(r'(\w+-\w+ \w+)\s+- - -', line)[0]
        meta = False
        cols['county'].extend([county, county])
        cols['precinct'].extend([precinct, precinct])
        cols['office'].extend(['Ballots Cast', 'Registered Voters'])
        cols['district'].extend(['',''])
        cols['party'].extend(['',''])
        cols['candidate'].extend(['',''])
        cols['election_day'].extend([election_day,''])
        cols['absentee'].extend([absentee,''])
        cols['early_voting'].extend([early_voting,''])
        cols['votes'].extend([votes, registered])
    elif re.search('VOTES=', line):
        office = re.findall(r'VOTES= [0-9.,]+ (.*)', line)[0]
        if re.search(r'Representative District (\d+)', office):
            office, district = office.split(' District ')
        else:
            district = ''
    elif re.search(r'\d%', line) and not meta: #Lines with percentage numbers that are not metadata are the values we want
        E, A, W, V, _, C = line.split(maxsplit=5) #The line is a row of a table of 6 columns
        if re.search(r'\(\w+\)', option):
            P = party_convert[
                re.findall(r'\((\w+)\)', C)[0]
            ]
            option = re.findall(r'\(\w+\) (.*)', C)[0]
        else:
            P = ''
        cols['county'].append(county)
        cols['precinct'].append(precinct)
        cols['office'].append(office)
        cols['district'].append(district)
        cols['party'].append(P)
        cols['candidate'].append(C)
        cols['election_day'].append(E)
        cols['absentee'].append(A)
        cols['early_voting'].append(W)
        cols['votes'].append(V)
    elif re.search(r'^Straight Party Votes Precinct ID: \d+ PartyName Votes \w+', line):
        #Note, the line ablve skips precincts that had no straight party votes for any party
        office = 'Straight Party'
        straights = re.split(r"\s*(\d+)\s*",re.findall(r'PartyName Votes (.*)', line)[0])[:-1]
        for i in range(len(straights)/2):
            
        #candidate = re.findall(r'(.*) \d+$', line)[0]
        #V = re.findall(r'.* (\d+)$', line)[0]
        #P = party_convert[line[0]]
        #cols['county'].append(county)
        #cols['precinct'].append(precinct)
        #cols['office'].append(office)
        #cols['district'].append(district)
        #cols['party'].append(P)
        #cols['candidate'].append(candidate)
        #cols['election_day'].append('')
        #cols['absentee'].append('')
        #cols['early_voting'].append('')
        #cols['votes'].append(V)
        meta = True
# Out:
# ['Democratic Party', '124', 'Republican Party', '104']
# ['Democratic Party', '97', 'Republican Party', '186']
# ['Democratic Party', '188', 'Republican Party', '156']
# ['Democratic Party', '50', 'Republican Party', '125']
# ['Democratic Party', '161', 'Republican Party', '45']
# ['Democratic Party', '113', 'Libertarian Party', '1', 'Republican Party', '360']
# ['Democratic Party', '192', 'Republican Party', '391']
# ['Democratic Party', '46', 'Republican Party', '163']
# ['Democratic Party', '129', 'Libertarian Party', '1', 'Republican Party', '311']
# ['Democratic Party', '105', 'Republican Party', '228', 'We The People', '1']
# ['Democratic Party', '131', 'Republican Party', '353']
# ['Democratic Party', '126', 'Republican Party', '246']
# ['Democratic Party', '105', 'Republican Party', '300']
# ['Democratic Party', '65', 'Republican Party', '142']
# ['Democratic Party', '102', 'Republican Party', '341']
# ['Democratic Party', '165', 'Republican Party', '509']
# ['Democratic Party', '139', 'Republican Party', '319']
# ['Democratic Party', '193', 'Republican Party', '657']
# ['Democratic Party', '87', 'Republican Party', '255']
# ['Democratic Party', '153', 'Republican Party', '402']
# ['Democratic Party', '26', 'Republican Party', '62']
# ['Democratic Party', '49', 'Republican Party', '96']
# ['Democratic Party', '100', 'Republican Party', '170']
# ['Democratic Party', '121', 'Republican Party', '191']
# ['Democratic Party', '179', 'Republican Party', '246']
# ['Democratic Party', '172', 'Libertarian Party', '1', 'Republican Party', '251']
# ['Democratic Party', '124', 'Republican Party', '220']
# ['Democratic Party', '156', 'Republican Party', '231']
# ['Democratic Party', '237', 'Libertarian Party', '1', 'Republican Party', '166']
# ['Democratic Party', '103', 'Republican Party', '116']
# ['Democratic Party', '99', 'Republican Party', '151', 'We The People', '1']
# ['Democratic Party', '85', 'Republican Party', '129']
# ['Democratic Party', '124', 'Republican Party', '164']
# ['Democratic Party', '156', 'Republican Party', '294']
# ['Democratic Party', '168', 'Republican Party', '125']
# ['Democratic Party', '264', 'Libertarian Party', '1', 'Republican Party', '311']
# ['Democratic Party', '152', 'Republican Party', '358']
# ['Democratic Party', '126', 'Republican Party', '131']
# ['Democratic Party', '117', 'Republican Party', '138']
# ['Democratic Party', '275', 'Republican Party', '140']
# ['Democratic Party', '24', 'Republican Party', '28']
# ['Democratic Party', '135', 'Republican Party', '216']
# ['Democratic Party', '143', 'Republican Party', '154']
# ['Democratic Party', '233', 'Republican Party', '238']
# ['Democratic Party', '162', 'Republican Party', '266']
# ['Democratic Party', '115', 'Republican Party', '328']
# ['Democratic Party', '104', 'Republican Party', '250']
# ['Democratic Party', '128', 'Republican Party', '390']
# ['Democratic Party', '119', 'Libertarian Party', '1', 'Republican Party', '282']
# ['Democratic Party', '174', 'Republican Party', '254']
# ['Democratic Party', '264', 'Republican Party', '217']
# ['Democratic Party', '158', 'Republican Party', '307']
# ['Democratic Party', '107', 'Republican Party', '106']
# ['Democratic Party', '93', 'Republican Party', '125']
# ['Democratic Party', '150', 'Republican Party', '231']
# ['Democratic Party', '117', 'Republican Party', '225']
# ['Democratic Party', '114', 'Republican Party', '179']
# ['Democratic Party', '144', 'Republican Party', '267', 'We The People', '1']
# ['Democratic Party', '134', 'Republican Party', '247']
# ['Democratic Party', '200', 'Libertarian Party', '1', 'Republican Party', '233', 'We The People', '1']
# ['Democratic Party', '108', 'Republican Party', '204']
# ['Democratic Party', '108', 'Republican Party', '36']
# ['Democratic Party', '219', 'Republican Party', '35']
# ['Democratic Party', '167', 'Republican Party', '28']
# ['Democratic Party', '123', 'Republican Party', '45']
# ['Democratic Party', '130', 'Republican Party', '43']
# ['Democratic Party', '149', 'Republican Party', '56']
# ['Democratic Party', '295', 'Republican Party', '40']
# ['Democratic Party', '302', 'Republican Party', '32']
# ['Democratic Party', '157', 'Republican Party', '14']
# ['Democratic Party', '142', 'Republican Party', '31']
# ['Democratic Party', '148', 'Republican Party', '13']
# ['Democratic Party', '204', 'Republican Party', '25']
# ['Democratic Party', '250', 'Republican Party', '19']
# ['Democratic Party', '231', 'Republican Party', '21']
# ['Democratic Party', '190', 'Republican Party', '25']
# ['Democratic Party', '192', 'Republican Party', '17', 'We The People', '1']
# ['Democratic Party', '197', 'Republican Party', '6']
# ['Democratic Party', '88', 'Republican Party', '274']
# ['Democratic Party', '10', 'Republican Party', '41']
# ['Democratic Party', '238', 'Republican Party', '26']
# ['Democratic Party', '515', 'Republican Party', '44']
# ['Democratic Party', '308', 'Republican Party', '30']
# ['Democratic Party', '254', 'Republican Party', '10', 'We The People', '1']
# ['Democratic Party', '306', 'Republican Party', '17']
# ['Democratic Party', '360', 'Republican Party', '34']
# ['Democratic Party', '341', 'Republican Party', '85']
# ['Democratic Party', '199', 'Libertarian Party', '1', 'Republican Party', '12']
# ['Democratic Party', '199', 'Republican Party', '8']
# ['Democratic Party', '286', 'Republican Party', '12']
# ['Democratic Party', '232', 'Republican Party', '9']
# ['Democratic Party', '270', 'Republican Party', '10']
# ['Democratic Party', '329', 'Republican Party', '14']
# ['Democratic Party', '232', 'Republican Party', '6']
# ['Democratic Party', '372', 'Republican Party', '20']
# ['Democratic Party', '101', 'Republican Party', '98']
# ['Democratic Party', '418', 'Republican Party', '10', 'We The People', '1']
# ['Democratic Party', '331', 'Republican Party', '14']
# ['Democratic Party', '368', 'Republican Party', '13', 'We The People', '1']
# ['Democratic Party', '313', 'Republican Party', '21']
# ['Democratic Party', '277', 'Republican Party', '12']
# ['Democratic Party', '279', 'Republican Party', '21']
# ['Democratic Party', '193', 'Republican Party', '7']
# ['Democratic Party', '145', 'Libertarian Party', '1', 'Republican Party', '11']
# ['Democratic Party', '445', 'Republican Party', '17']
# ['Democratic Party', '285', 'Republican Party', '10']
# ['Democratic Party', '414', 'Republican Party', '16', 'We The People', '1']
# ['Democratic Party', '241', 'Republican Party', '10']
# ['Democratic Party', '345', 'Libertarian Party', '1', 'Republican Party', '13']
# ['Democratic Party', '405', 'Republican Party', '13']
# ['Democratic Party', '290', 'Republican Party', '15']
# ['Democratic Party', '271', 'Republican Party', '19']
# ['Democratic Party', '139', 'Republican Party', '5']
# ['Democratic Party', '86', 'Republican Party', '136']
# ['Democratic Party', '189', 'Republican Party', '10']
# ['Democratic Party', '178', 'Republican Party', '5']
# ['Democratic Party', '237', 'Republican Party', '16']
# ['Democratic Party', '103', 'Republican Party', '7']
# ['Democratic Party', '242', 'Republican Party', '15']
# ['Democratic Party', '277', 'Libertarian Party', '2', 'Republican Party', '12']
# ['Democratic Party', '2', 'Republican Party', '2']
# ['Democratic Party', '354', 'Republican Party', '18']
# ['Democratic Party', '202', 'Libertarian Party', '1', 'Republican Party', '9']
# ['Democratic Party', '156', 'Republican Party', '14']
# ['Democratic Party', '221', 'Republican Party', '14']
# ['Democratic Party', '239', 'Republican Party', '20']
# ['Democratic Party', '320', 'Republican Party', '22']
# ['Democratic Party', '316', 'Republican Party', '26']
# ['Democratic Party', '362', 'Republican Party', '23']
# ['Democratic Party', '125', 'Republican Party', '96']
# ['Democratic Party', '127', 'Republican Party', '41']
# ['Democratic Party', '131', 'Republican Party', '110']
# ['Democratic Party', '97', 'Republican Party', '100']
# ['Democratic Party', '200', 'Republican Party', '195']
# ['Democratic Party', '106', 'Libertarian Party', '1', 'Republican Party', '121']
# ['Democratic Party', '119', 'Republican Party', '125']
# ['Democratic Party', '234', 'Republican Party', '207']
# ['Democratic Party', '212', 'Libertarian Party', '1', 'Republican Party', '174']
# ['Democratic Party', '128', 'Republican Party', '22']
# ['Democratic Party', '102', 'Republican Party', '70']
# ['Democratic Party', '232', 'Republican Party', '193']
# ['Democratic Party', '46', 'Republican Party', '38']
# ['Democratic Party', '108', 'Republican Party', '53']
# ['Democratic Party', '210', 'Libertarian Party', '1', 'Republican Party', '112']
# ['Democratic Party', '181', 'Republican Party', '97']
# ['Democratic Party', '173', 'Republican Party', '107']
# ['Democratic Party', '146', 'Republican Party', '76']
# ['Democratic Party', '187', 'Republican Party', '103']
# ['Democratic Party', '202', 'Republican Party', '112']
# ['Democratic Party', '138', 'Republican Party', '86']
# ['Democratic Party', '167', 'Libertarian Party', '1', 'Republican Party', '82']
# ['Democratic Party', '99', 'Republican Party', '21']
# ['Democratic Party', '208', 'Republican Party', '74']
# ['Democratic Party', '190', 'Libertarian Party', '1', 'Republican Party', '67', 'We The People', '1']
# ['Democratic Party', '169', 'Republican Party', '70']
# ['Democratic Party', '109', 'Republican Party', '61']
# ['Democratic Party', '178', 'Republican Party', '57']
# ['Democratic Party', '263', 'Republican Party', '86']
# ['Democratic Party', '232', 'Republican Party', '47']
# ['Democratic Party', '190', 'Republican Party', '13']
# ['Democratic Party', '249', 'Republican Party', '43']
# ['Democratic Party', '217', 'Republican Party', '24']
# ['Democratic Party', '171', 'Republican Party', '86']
# ['Democratic Party', '105', 'Republican Party', '52']
# ['Democratic Party', '289', 'Republican Party', '118']
# ['Democratic Party', '214', 'Republican Party', '110']
# ['Democratic Party', '179', 'Republican Party', '121']
# ['Democratic Party', '130', 'Republican Party', '46']
# ['Democratic Party', '268', 'Republican Party', '156']
# ['Democratic Party', '243', 'Republican Party', '94']
# ['Democratic Party', '150', 'Republican Party', '125']
# ['Democratic Party', '145', 'Republican Party', '58']
# ['Democratic Party', '250', 'Republican Party', '127']
# ['Democratic Party', '252', 'Libertarian Party', '2', 'Republican Party', '103']
# ['Democratic Party', '173', 'Republican Party', '92']
# ['Democratic Party', '112', 'Republican Party', '91']
# ['Democratic Party', '223', 'Republican Party', '141']
# ['Democratic Party', '322', 'Republican Party', '133']
# ['Democratic Party', '180', 'Republican Party', '96']
# ['Democratic Party', '153', 'Republican Party', '96']
# ['Democratic Party', '137', 'Republican Party', '46']
# ['Democratic Party', '175', 'Republican Party', '105']
# ['Democratic Party', '174', 'Republican Party', '42']
# ['Democratic Party', '110', 'Republican Party', '56']
# ['Democratic Party', '221', 'Republican Party', '96']
# ['Democratic Party', '198', 'Republican Party', '57', 'We The People', '1']
# ['Democratic Party', '108', 'Republican Party', '57']
# ['Democratic Party', '147', 'Republican Party', '125']
# ['Democratic Party', '229', 'Republican Party', '224']
# ['Democratic Party', '189', 'Libertarian Party', '1', 'Republican Party', '153']
# ['Democratic Party', '173', 'Republican Party', '176']
# ['Democratic Party', '126', 'Republican Party', '137']
# ['Democratic Party', '201', 'Republican Party', '185']
# ['Democratic Party', '208', 'Republican Party', '194']
# ['Democratic Party', '83', 'Republican Party', '91']
# ['Democratic Party', '140', 'Republican Party', '151']
# ['Democratic Party', '155', 'Republican Party', '144']
# ['Democratic Party', '101', 'Republican Party', '98']
# ['Democratic Party', '189', 'Libertarian Party', '1', 'Republican Party', '199']
# ['Democratic Party', '157', 'Republican Party', '127']
# ['Democratic Party', '185', 'Republican Party', '190']
# ['Democratic Party', '122', 'Republican Party', '146']
# ['Democratic Party', '254', 'Republican Party', '98']
# ['Democratic Party', '219', 'Republican Party', '237']
# ['Democratic Party', '239', 'Republican Party', '166']
# ['Democratic Party', '139', 'Republican Party', '159']
# ['Democratic Party', '183', 'Republican Party', '214']
# ['Democratic Party', '172', 'Republican Party', '83']
# ['Democratic Party', '223', 'Republican Party', '158']
# ['Democratic Party', '157', 'Republican Party', '154']
# ['Democratic Party', '181', 'Republican Party', '235']
# ['Democratic Party', '185', 'Republican Party', '195']
# ['Democratic Party', '114', 'Republican Party', '109']
# ['Democratic Party', '245', 'Republican Party', '188', 'We The People', '2']
# ['Democratic Party', '306', 'Republican Party', '227', 'We The People', '1']
# ['Democratic Party', '178', 'Republican Party', '106']
# ['Democratic Party', '60', 'Republican Party', '53']
# ['Democratic Party', '181', 'Republican Party', '190']
# ['Democratic Party', '245', 'Republican Party', '278', 'We The People', '1']
# ['Democratic Party', '137', 'Republican Party', '112']
# ['Democratic Party', '123', 'Republican Party', '113']
# ['Democratic Party', '248', 'Libertarian Party', '1', 'Republican Party', '157']
# ['Democratic Party', '160', 'Republican Party', '150', 'We The People', '1']
# ['Democratic Party', '26', 'Republican Party', '29']
# ['Democratic Party', '10', 'Republican Party', '4']
# ['Democratic Party', '41', 'Republican Party', '256']
# ['Democratic Party', '109', 'Republican Party', '306']
# ['Democratic Party', '97', 'Republican Party', '158']
# ['Democratic Party', '94', 'Republican Party', '100']
# ['Democratic Party', '84', 'Libertarian Party', '1', 'Republican Party', '99']
# ['Democratic Party', '3', 'Republican Party', '5']
# ['Democratic Party', '58', 'Republican Party', '61']
# ['Democratic Party', '30', 'Republican Party', '38']
# ['Democratic Party', '68', 'Republican Party', '103']
# ['Democratic Party', '94', 'Republican Party', '83']
# ['Democratic Party', '120', 'Republican Party', '104']
# ['Democratic Party', '61', 'Republican Party', '65']
# ['Democratic Party', '182', 'Republican Party', '222']
# ['Democratic Party', '121', 'Republican Party', '141']
# ['Democratic Party', '198', 'Republican Party', '119']
# ['Democratic Party', '268', 'Republican Party', '229']
# ['Democratic Party', '204', 'Republican Party', '151']
# ['Democratic Party', '160', 'Libertarian Party', '1', 'Republican Party', '103']
# ['Democratic Party', '126', 'Republican Party', '90']
# ['Democratic Party', '198', 'Republican Party', '169']
# ['Democratic Party', '145', 'Republican Party', '119']
# ['Democratic Party', '153', 'Republican Party', '134']
# ['Democratic Party', '231', 'Republican Party', '201']
# ['Democratic Party', '141', 'Republican Party', '116']
# ['Democratic Party', '154', 'Republican Party', '131']
# ['Democratic Party', '110', 'Republican Party', '97']
# ['Democratic Party', '117', 'Republican Party', '89']
# ['Democratic Party', '190', 'Republican Party', '160']
# ['Democratic Party', '233', 'Republican Party', '212']
# ['Democratic Party', '127', 'Republican Party', '109']
# ['Democratic Party', '124', 'Republican Party', '83']
# ['Democratic Party', '218', 'Libertarian Party', '1', 'Republican Party', '197']
# ['Democratic Party', '217', 'Republican Party', '213']
# ['Democratic Party', '150', 'Republican Party', '119']
# ['Democratic Party', '237', 'Republican Party', '37', 'We The People', '1']
# ['Democratic Party', '88', 'Republican Party', '103']
# ['Democratic Party', '246', 'Republican Party', '85']
# ['Democratic Party', '457', 'Republican Party', '98']
# ['Democratic Party', '454', 'Republican Party', '169', 'We The People', '1']
# ['Democratic Party', '278', 'Republican Party', '110']
# ['Democratic Party', '150', 'Republican Party', '51']
# ['Democratic Party', '318', 'Republican Party', '35']
# ['Democratic Party', '292', 'Republican Party', '28', 'We The People', '1']
# ['Democratic Party', '196', 'Republican Party', '25']
# ['Democratic Party', '229', 'Republican Party', '238']
# ['Democratic Party', '358', 'Republican Party', '62']
# ['Democratic Party', '260', 'Republican Party', '57']
# ['Democratic Party', '304', 'Libertarian Party', '1', 'Republican Party', '58']
# ['Democratic Party', '290', 'Republican Party', '52']
# ['Democratic Party', '211', 'Republican Party', '33']
# ['Democratic Party', '346', 'Republican Party', '130']
# ['Democratic Party', '454', 'Republican Party', '65']
# ['Democratic Party', '224', 'Republican Party', '45']
# ['Democratic Party', '210', 'Republican Party', '54']
# ['Democratic Party', '209', 'Republican Party', '38']
# ['Democratic Party', '184', 'Republican Party', '104']
# ['Democratic Party', '403', 'Republican Party', '91']
# ['Democratic Party', '305', 'Republican Party', '87']
# ['Democratic Party', '23', 'Republican Party', '33']
# ['Democratic Party', '140', 'Republican Party', '251']
# ['Democratic Party', '156', 'Republican Party', '112']
# ['Democratic Party', '97', 'Republican Party', '144']
# ['Democratic Party', '145', 'Republican Party', '242']
# ['Democratic Party', '156', 'Republican Party', '210']
# ['Democratic Party', '219', 'Republican Party', '216']
# ['Democratic Party', '192', 'Republican Party', '228']
# ['Democratic Party', '149', 'Republican Party', '292']
# ['Democratic Party', '154', 'Republican Party', '134', 'We The People', '1']
# ['Democratic Party', '215', 'Republican Party', '221']
# ['Democratic Party', '224', 'Libertarian Party', '1', 'Republican Party', '250']
# ['Democratic Party', '107', 'Republican Party', '143']
# ['Democratic Party', '111', 'Republican Party', '160']
# ['Democratic Party', '142', 'Republican Party', '103']
# ['Democratic Party', '300', 'Republican Party', '250']
# ['Democratic Party', '153', 'Republican Party', '141']
# ['Democratic Party', '86', 'Republican Party', '157']
# ['Democratic Party', '123', 'Republican Party', '233']
# ['Democratic Party', '207', 'Republican Party', '204']
# ['Democratic Party', '190', 'Republican Party', '189']
# ['Democratic Party', '174', 'Republican Party', '146']
# ['Democratic Party', '69', 'Republican Party', '236']
# ['Democratic Party', '107', 'Republican Party', '243']
# ['Democratic Party', '105', 'Republican Party', '274']
# ['Democratic Party', '74', 'Republican Party', '180']
# ['Democratic Party', '176', 'Republican Party', '423']
# ['Democratic Party', '118', 'Republican Party', '274']
# ['Democratic Party', '134', 'Republican Party', '279']
# ['Democratic Party', '70', 'Republican Party', '178']
# ['Democratic Party', '113', 'Republican Party', '177']
# ['Republican Party', '1']
# ['Democratic Party', '170', 'Republican Party', '529']
# ['Democratic Party', '344', 'Republican Party', '699']
# ['Democratic Party', '58', 'Republican Party', '61']
# ['Democratic Party', '125', 'Republican Party', '323']
# ['Democratic Party', '168', 'Republican Party', '375', 'We The People', '1']
# ['Democratic Party', '131', 'Republican Party', '328']
# ['Democratic Party', '16', 'Republican Party', '21']
# ['Democratic Party', '63', 'Republican Party', '174']
# ['Democratic Party', '136', 'Republican Party', '379']
# ['Democratic Party', '40', 'Republican Party', '66']
# ['Democratic Party', '122', 'Libertarian Party', '2', 'Republican Party', '239']
# ['Democratic Party', '143', 'Republican Party', '179']
# ['Democratic Party', '134', 'Republican Party', '282']
# ['Democratic Party', '111', 'Republican Party', '217']
# ['Democratic Party', '179', 'Republican Party', '77']
# ['Democratic Party', '183', 'Republican Party', '90']
# ['Democratic Party', '144', 'Republican Party', '59']
# ['Democratic Party', '4', 'Republican Party', '33']
# ['Democratic Party', '97', 'Republican Party', '484']
# ['Democratic Party', '112', 'Republican Party', '441']
# ['Democratic Party', '116', 'Republican Party', '390']
# ['Democratic Party', '99', 'Libertarian Party', '1', 'Republican Party', '234']
# ['Democratic Party', '148', 'Republican Party', '201']
# ['Democratic Party', '65', 'Republican Party', '169']
# ['Democratic Party', '162', 'Republican Party', '263']
# ['Democratic Party', '118', 'Republican Party', '294']
# ['Democratic Party', '90', 'Republican Party', '316']
# ['Democratic Party', '80', 'Republican Party', '212']
# ['Democratic Party', '175', 'Libertarian Party', '1', 'Republican Party', '258']
# ['Democratic Party', '302', 'Republican Party', '601', 'We The People', '1']

# %%
df = pd.DataFrame(data=cols)
df
# Out:
#       county    precinct                                    office district  \
# 0       Lake  001-CAL 05                              Ballots Cast
# 1       Lake  001-CAL 05                         Registered Voters
# 2       Lake  001-CAL 05           Public Question-Const Amendment
# 3       Lake  001-CAL 05           Public Question-Const Amendment
# 4       Lake  001-CAL 05  President and Vice-President of the U.S.
# ...      ...         ...                                       ...      ...
# 16818   Lake   348-WT 10   Lake Superior Court Criminal Div Room 1
# 16819   Lake   348-WT 10   Lake Superior Court Criminal Div Room 2
# 16820   Lake   348-WT 10   Lake Superior Court Criminal Div Room 2
# 16821   Lake   348-WT 10      Lake Superior Court Civil Div Room 6
# 16822   Lake   348-WT 10      Lake Superior Court Civil Div Room 6
#
#       party          candidate election_day absentee early_voting votes
# 0                                       195       21          153   369
# 1                                                                   771
# 2                          Yes          100        4           73   177
# 3                           No           68        6           59   133
# 4            (D) Harris \ Walz           81       12           90   183
# ...     ...                ...          ...      ...          ...   ...
# 16818                       No          130        5          236   371
# 16819                      Yes          300       29          532   861
# 16820                       No          132        7          226   365
# 16821                      Yes          296       29          522   847
# 16822                       No          140        8          240   388
#
# [16823 rows x 10 columns]

# %%
df.to_csv(output_file)
