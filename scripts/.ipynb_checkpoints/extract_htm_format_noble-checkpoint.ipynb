# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import pandas as pd
import re
import itertools as it

# %%
counties = ['Noble']
url = 'https://www.in.gov/counties/noble/election-info/historical-election-info/2024-general-election-by-precinct/'

# %%
i = 0
county = counties[i]
print(county)
# Out:
# Noble

# %%
output_file = "../data/in_2024_results/" + county + ".csv"
output_2 = "C:/Users/johnsor/Documents/openelections-data-in/2024/counties/20241105__in__general__" + str.lower(county) + "__precinct.csv"
output_2
# Out:
# 'C:/Users/johnsor/Documents/openelections-data-in/2024/counties/20241105__in__general__noble__precinct.csv'

# %%
req = Request(url)
html_page = urlopen(req).read()
soup = BeautifulSoup(html_page, 'html.parser')
data = soup.find('section', {'id' : 'content_container_864015'})

# %%
cols = {'county' : [],
        'precinct' : [],
        'office' : [],
        'district' : [],
        'party' : [],
        'candidate' : [],
        'election_day' : [],
        'absentee' : [],
        'early_voting' : [],
        'votes' : []}
party_convert = {'R' : 'REP',
                 'REP' : 'REP',
                 'D' : 'DEM',
                 'DEM' : 'DEM',
                 'L' : 'LIB',
                 'LIB' : 'LIB',
                 'WTP' : 'WTP',
                 'W' : 'WTP',
                 'NP' : ''
                }

# %%
for div in data.find_all('div'):
    if div.attrs['class'] == ['s5_']:
        election_day = div.find('span', {'class' : 'f91_'}).text
        absentee = div.find('span', {'class' : 'f90_'}).text
        early_voting = div.find('span', {'class' : 'f89_'}).text
        votes = div.find('span', {'class' : 'f92_'}).text
        registered = div.find('span', {'class' : 'f100_'}).text
    elif div.attrs['class'] == ['s7_']:
        precinct = re.search('Precinct Name: (.*)',
            div.find('span', {'class' : 'f42_'}).text).group(1)
        cols['county'].extend([county, county])
        cols['precinct'].extend([precinct, precinct])
        cols['office'].extend(['Ballots Cast', 'Registered Voters'])
        cols['district'].extend(['',''])
        cols['party'].extend(['',''])
        cols['candidate'].extend(['',''])
        cols['election_day'].extend([election_day,''])
        cols['absentee'].extend([absentee,''])
        cols['early_voting'].extend([early_voting,''])
        cols['votes'].extend([votes, registered])
    elif div.attrs['class'] == ['s9_']:
        office = div.find('span', {'class' : 'f0_'}).text
        print(office)
    elif div.attrs['class'] == ['s0_']:
        election_day = div.find('span', {'class' : 'f13_'}).text
        absentee = div.find('span', {'class' : 'f12_'}).text
        early_voting = div.find('span', {'class' : 'f11_'}).text
        votes = div.find('span', {'class' : 'f10_'}).text
        candidate = div.find('span', {'class' : 'f8_'}).text
        print(candidate)
# Out:
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# West Noble School Board District 7
# (NP) Joseph Saggars
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# Central Noble SB Jefferson Township
# (NP) Amanda Lock
# Central Noble School Board York Township
# (NP) Tyler Schuller
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# Central Noble SB Jefferson Township
# (NP) Amanda Lock
# Central Noble School Board York Township
# (NP) Tyler Schuller
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# Smith-Green School Board District 1
# (NP) Emily Putt
# Smith-Green School Board District 2
# (NP) Brian E. Clark
# Smith-Green School Board District 3
# (NP) Jermiah Johnson
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# Central Noble SB Jefferson Township
# (NP) Amanda Lock
# Central Noble School Board York Township
# (NP) Tyler Schuller
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# Lakeland School Board Member District 3
# (NP) Derrick M. Sherck
# Lakeland School Board Member District 4
# (NP) Sue A. Keenan
# Lakeland School Board Member District 5
# (NP) Shelley L. Gould
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 52
# (R) Ben Smaltz
# (D) Walt Sorg
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# East Noble School Board Member At-Large
# (NP) Joel H. Lash
# (NP) David A. Pine
# East Noble School Board Orange Township
# (NP) Aaron (Aj) Byerley
# (NP) John Klaassen
# East Noble School Board Swan Township
# (NP) Scott L. Truelove
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# Central Noble SB Jefferson Township
# (NP) Amanda Lock
# Central Noble School Board York Township
# (NP) Tyler Schuller
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No
# Public Question-Const Amendment
# Yes
# No
# President and Vice-President of the U.S.
# (R) Trump \ Vance
# (D) Harris \ Walz
# (L) Oliver \ Ter Maat
# (WTP) Kennedy Jr. \ Shanahan
# Write-In
# United States Senator
# (R) Jim Banks
# (D) Valerie McCray
# (L) Andrew Horning
# Write-In
# Governor And Lieutenant Governor
# (R) Braun \ Beckwith
# (D) Mccormick \ Goodin
# (L) Rainwater \ Hudson
# Write-In
# Attorney General
# (R) Todd Rokita
# (D) Destiny Wells
# United States Representative District 3
# (R) Marlin A. Stutzman
# (D) Kiley M. Adolph
# (L) Jarrad Lancaster
# Write-In
# State Senator District 13
# (R) C. Susan Glick
# State Representative District 18
# (R) David H. Abbott
# Judge of the Superior Court No. 1
# (R) Steven Thomas Clouse
# Circuit Court Clerk
# (R) Tammy Bremer
# County Treasurer
# (R) Rob Tomlinson
# County Coroner
# (R) Lisa S. Strebig
# (I) Brad Wyatt
# County Surveyor
# (R) Randolph (Randy) Sexton
# County Commissioner District 2
# (R) Gary D. Leatherman
# County Commissioner District 3
# (R) Anita F. Hess
# (I) Kelly K. Kammerer
# County Council Member At Large
# (REP) Doug A. Harp
# (REP) Casey R. Myers
# (REP) Mary M. Wysong
# (DEM) Troy Hornberger
# (DEM) Robert M. Kurzeja
# (DEM) Michael Quintanilla
# Central Noble SB Jefferson Township
# (NP) Amanda Lock
# Central Noble School Board York Township
# (NP) Tyler Schuller
# IN Supreme Court-Rush
# Yes
# No
# IN Supreme Court-Massa
# Yes
# No
# IN Supreme Court-Molter
# Yes
# No
# Court of Appeals Dist 4-Pyle III
# Yes
# No

# %%
df = pd.DataFrame(data=cols)
df
# Out:
#    county               precinct             office district party candidate  \
# 0   Noble           Washington 1       Ballots Cast
# 1   Noble           Washington 1  Registered Voters
# 2   Noble               Sparta 2       Ballots Cast
# 3   Noble               Sparta 2  Registered Voters
# 4   Noble                Perry 3       Ballots Cast
# 5   Noble                Perry 3  Registered Voters
# 6   Noble                Perry 4       Ballots Cast
# 7   Noble                Perry 4  Registered Voters
# 8   Noble                Perry 5       Ballots Cast
# 9   Noble                Perry 5  Registered Voters
# 10  Noble                Perry 6       Ballots Cast
# 11  Noble                Perry 6  Registered Voters
# 12  Noble              Elkhart 7       Ballots Cast
# 13  Noble              Elkhart 7  Registered Voters
# 14  Noble                 York 8       Ballots Cast
# 15  Noble                 York 8  Registered Voters
# 16  Noble                Noble 9       Ballots Cast
# 17  Noble                Noble 9  Registered Voters
# 18  Noble               Green 10       Ballots Cast
# 19  Noble               Green 10  Registered Voters
# 20  Noble           Jefferson 11       Ballots Cast
# 21  Noble           Jefferson 11  Registered Voters
# 22  Noble              Orange 12       Ballots Cast
# 23  Noble              Orange 12  Registered Voters
# 24  Noble              Orange 13       Ballots Cast
# 25  Noble              Orange 13  Registered Voters
# 26  Noble              Orange 14       Ballots Cast
# 27  Noble              Orange 14  Registered Voters
# 28  Noble               Wayne 15       Ballots Cast
# 29  Noble               Wayne 15  Registered Voters
# 30  Noble               Wayne 16       Ballots Cast
# 31  Noble               Wayne 16  Registered Voters
# 32  Noble               Wayne 17       Ballots Cast
# 33  Noble               Wayne 17  Registered Voters
# 34  Noble               Wayne 18       Ballots Cast
# 35  Noble               Wayne 18  Registered Voters
# 36  Noble               Wayne 19       Ballots Cast
# 37  Noble               Wayne 19  Registered Voters
# 38  Noble               Wayne 20       Ballots Cast
# 39  Noble               Wayne 20  Registered Voters
# 40  Noble               Wayne 21       Ballots Cast
# 41  Noble               Wayne 21  Registered Voters
# 42  Noble               Wayne 22       Ballots Cast
# 43  Noble               Wayne 22  Registered Voters
# 44  Noble  Kendallville-Allen 23       Ballots Cast
# 45  Noble  Kendallville-Allen 23  Registered Voters
# 46  Noble  Kendallville-Allen 24       Ballots Cast
# 47  Noble  Kendallville-Allen 24  Registered Voters
# 48  Noble               Allen 25       Ballots Cast
# 49  Noble               Allen 25  Registered Voters
# 50  Noble               Allen 26       Ballots Cast
# 51  Noble               Allen 26  Registered Voters
# 52  Noble                Swan 27       Ballots Cast
# 53  Noble                Swan 27  Registered Voters
# 54  Noble              Albion 28       Ballots Cast
# 55  Noble              Albion 28  Registered Voters
# 56  Noble               Noble 29       Ballots Cast
# 57  Noble               Noble 29  Registered Voters
#
#    election_day absentee early_voting votes
# 0           259       24          247   530
# 1                                       811
# 2           443       37          520  1000
# 3                                      1738
# 4           263       22          250   535
# 5                                      1087
# 6           138        5           94   237
# 7                                       612
# 8            95        8           64   167
# 9                                       465
# 10          286       31          195   512
# 11                                     1161
# 12          263       16          294   573
# 13                                      902
# 14          346       22          446   814
# 15                                     1172
# 16          426       27          397   850
# 17                                     1279
# 18          452       38          609  1099
# 19                                     1454
# 20          307       23          529   859
# 21                                     1224
# 22          378       20          204   602
# 23                                      997
# 24          433       68          427   928
# 25                                     1317
# 26          187       10           63   260
# 27                                      516
# 28          268       46          240   554
# 29                                      859
# 30          411       77          545  1033
# 31                                     1533
# 32          193       57          218   468
# 33                                      981
# 34          465       52          520  1037
# 35                                     1871
# 36          260       12          181   453
# 37                                      836
# 38          161        6           67   234
# 39                                      561
# 40          269       24          218   511
# 41                                      929
# 42           62        2           52   116
# 43                                      170
# 44          345       20          217   582
# 45                                     1360
# 46          343       34          376   753
# 47                                     1121
# 48          505       47          369   921
# 49                                     1311
# 50          382       26          270   678
# 51                                     1215
# 52          697       83          545  1325
# 53                                     1812
# 54          392       47          447   886
# 55                                     1501
# 56          329       35          314   678
# 57                                      967

# %%
line = lines[125]
print(re.findall(r'\d+-(\w+\s?\w*)\s+- - -', line))
# Out:
# []

# %%
cols = {'county' : [],
        'precinct' : [],
        'office' : [],
        'district' : [],
        'party' : [],
        'candidate' : [],
        'election_day' : [],
        'absentee' : [],
        'early_voting' : [],
        'votes' : []}
party_convert = {'R' : 'REP',
                 'REP' : 'REP',
                 'D' : 'DEM',
                 'DEM' : 'DEM',
                 'L' : 'LIB',
                 'LIB' : 'LIB',
                 'WTP' : 'WTP',
                 'W' : 'WTP',
                 'NP' : '',
                 'I' : 'IND',
                 'IND' : 'IND'
                }

# %%
vote = False #Signifies when a "VOTE FOR ..." line has occurred
for line in lines: #for each line of the page
    if re.search(' EMS ', line):
        print(repr(line))
        election_day = re.findall(r'#\s+Of\s+Election\s+Day\s+(\d+)', line)[0]
        absentee = re.findall(r'# Of Paper Absentee (\d+)', line)[0]
        early_voting = re.findall(r'# Of Walk-In Absentee (\d+)', line)[0]
        votes = re.findall(r'PUBLIC COUNT: (\d+)', line)[0]
        registered = re.findall(r'REGISTERED VOTERS: (\d+)', line)[0]
        meta = True
    elif re.search('- - -', line):
        precinct = re.findall(r'\d+-(\w+\s*\w*\s*\w*)\s+- - -', line)[0]
        precinct = re.sub('\xa0', '', precinct) #Looking at you NEW DURHAM 01 in Laporte
        meta = False
        cols['county'].extend([county, county])
        cols['precinct'].extend([precinct, precinct])
        cols['office'].extend(['Ballots Cast', 'Registered Voters'])
        cols['district'].extend(['',''])
        cols['party'].extend(['',''])
        cols['candidate'].extend(['',''])
        cols['election_day'].extend([election_day,''])
        cols['absentee'].extend([absentee,''])
        cols['early_voting'].extend([early_voting,''])
        cols['votes'].extend([votes, registered])
    elif re.search('VOTES=', line):
        office = re.findall(r'VOTES= [0-9.,]+ (.*)', line)[0]
        if re.search(r'[Senator|Representative] District (\d+)', office):
            office, district = office.split(' District ')
        else:
            district = ''
    elif re.search(r'\d%', line) and not meta: #Lines with percentage numbers that are not metadata are the values we want
        E, A, W, V, _, C = line.split(maxsplit=5) #The line is a row of a table of 6 columns
        if re.search(r'\(\w+\)', C):
            P = party_convert[
                re.findall(r'\((\w+)\)', C)[0]
            ]
            C = re.findall(r'\(\w+\) (.*)', C)[0]
        else:
            P = ''
        cols['county'].append(county)
        cols['precinct'].append(precinct)
        cols['office'].append(office)
        cols['district'].append(district)
        cols['party'].append(P)
        cols['candidate'].append(C)
        cols['election_day'].append(E)
        cols['absentee'].append(A)
        cols['early_voting'].append(W)
        cols['votes'].append(V)
    elif re.search(r'^Straight Party Votes Precinct ID: \d+ PartyName Votes \w+', line):
        #Note, the line ablve skips precincts that had no straight party votes for any party
        office = 'Straight Party'
        straights = re.split(r"\s*(\d+)\s*",re.findall(r'PartyName Votes (.*)', line)[0])[:-1]
        for i in range(len(straights)//2):
            party, votes = straights[2*i:2*i+2]
            P = party_convert[party[0]]
            cols['county'].append(county)
            cols['precinct'].append(precinct)
            cols['office'].append(office)
            cols['district'].append('')
            cols['party'].append(P)
            cols['candidate'].append(party)
            cols['election_day'].append('')
            cols['absentee'].append('')
            cols['early_voting'].append('')
            cols['votes'].append(votes)
        meta = True
# Out:
# 'Precinct Summary Report 11/6/2024 - 9:34:57 AM  Election Date: 11/5/2024 EMS \xa0 Noble County, Indiana 2024 General Election INNOBG24 11/5/2024 \xa0 All Precincts E- # OF  Election Day 9358 NUMBER OF PRECINCTS: 29 A- # OF  Paper Absentee 919 # OF PRECINCTS REPORTED: 0 8918 W- # OF  Walk-In Absentee # OF PRECINCTS NOT REPORTED: 0 \xa0PUBLIC COUNT: 19195 # OF PRECINCTS INCOMPLETE: 29 \xa0VOTER TURNOUT: 60.43% # OF EQUIPMENT PROGRAMMED: 76 \xa0REGISTERED VOTERS: 31762 # OF EQUIPMENT REPORTED: 74'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 5
#       3 if re.search(' EMS ', line):
#       4     print(repr(line))
# ----> 5     election_day = re.findall(r'#\s+Of\s+Election\s+Day\s+(\d+)', line)[0]
#       6     absentee = re.findall(r'# Of Paper Absentee (\d+)', line)[0]
#       7     early_voting = re.findall(r'# Of Walk-In Absentee (\d+)', line)[0]
#
# IndexError: list index out of range

# %%
df = pd.DataFrame(data=cols)
df
# Out:
#       county precinct                                    office district  \
# 0       Lake   CAL 05                              Ballots Cast
# 1       Lake   CAL 05                         Registered Voters
# 2       Lake   CAL 05           Public Question-Const Amendment
# 3       Lake   CAL 05           Public Question-Const Amendment
# 4       Lake   CAL 05  President and Vice-President of the U.S.
# ...      ...      ...                                       ...      ...
# 17557   Lake    WT 10      Lake Superior Court Civil Div Room 6
# 17558   Lake    WT 10      Lake Superior Court Civil Div Room 6
# 17559   Lake    WT 10                            Straight Party
# 17560   Lake    WT 10                            Straight Party
# 17561   Lake    WT 10                            Straight Party
#
#       party         candidate election_day absentee early_voting votes
# 0                                      195       21          153   369
# 1                                                                  771
# 2                         Yes          100        4           73   177
# 3                          No           68        6           59   133
# 4       DEM     Harris \ Walz           81       12           90   183
# ...     ...               ...          ...      ...          ...   ...
# 17557                     Yes          296       29          522   847
# 17558                      No          140        8          240   388
# 17559   DEM  Democratic Party                                      302
# 17560   REP  Republican Party                                      601
# 17561   WTP     We The People                                        1
#
# [17562 rows x 10 columns]

# %%
df['precinct']
# Out:
# 0        CAL 05
# 1        CAL 05
# 2        CAL 05
# 3        CAL 05
# 4        CAL 05
#           ...
# 17557     WT 10
# 17558     WT 10
# 17559     WT 10
# 17560     WT 10
# 17561     WT 10
# Name: precinct, Length: 17562, dtype: object

# %%
df.to_csv(output_file)

# %%
df.to_csv(output_2, index=False, encoding='utf-8')
