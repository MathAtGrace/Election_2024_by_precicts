# %%
import pandas as pd
import numpy as np
import re
import pymupdf
import pdfplumber

# %%
counties = ["Elkhart"]

# %%
i = 0
county = counties[i]
county
# Out:
# 'Elkhart'

# %%
input_file = "../data-raw/in_2024_results/" + county + ".pdf"
output_file = "../data/in_2024_results/" + county + ".csv"
output_2 = "C:/Users/johnsor/Documents/openelections-data-in/2024/counties/20241105__in__general__" + str.lower(county) + "__precinct.csv"
output_2
# Out:
# 'C:/Users/johnsor/Documents/openelections-data-in/2024/counties/20241105__in__general__elkhart__precinct.csv'

# %%
doc = pymupdf.open(input_file) # open a document
df = pd.DataFrame({'county' : [], 'precinct' : [], 'office' : [], 'district' : [], 'party' : [], 'candidate' : [], 'votes' : []})

# %%
page = doc[0]
page
# Out:
# page 0 of ../data-raw/in_2024_results/Elkhart.pdf

# %%
blocks = page.get_text_blocks()
df_page = pd.DataFrame(blocks, columns=('tl.x', 'tl.y', 'br.x', 'br.y', 'text', 'index', 'type')) #put the blocks into a dataframe
df_page.sort_values(by=['tl.y'],inplace=True)
df_page
# Out:
#           tl.x        tl.y        br.x        br.y  \
# 0    37.553001   48.365658  330.481445   78.644569
# 1    37.283001   89.984001  586.350220   99.976006
# 2   257.617004  111.103996  361.058075  121.096001
# 20  417.009003  112.346352  477.821045  120.673439
# 5   250.792999  133.381668  252.247269  145.038574
# 7   410.028992  133.381668  412.210663  145.038574
# 3   142.792999  133.381668  144.247269  145.038574
# 8   410.028992  133.466354  508.732422  155.598572
# 4   142.792999  143.461624  144.247269  155.118530
# 6   250.792999  143.461624  252.247269  155.118530
# 9   503.726990  144.026352  508.112823  152.353424
# 10  142.792999  152.722351  508.779083  163.547424
# 11  142.792999  162.661636  508.829681  176.027466
# 12  142.792999  173.221634  508.472839  187.278564
# 13  142.792999  183.781631  551.445068  197.838562
# 14  142.792999  194.341629  551.493286  205.998535
# 15  142.792999  206.821671  552.825745  218.478577
# 16  142.792999  215.461624  551.445068  228.558533
# 17  142.792999  227.885620  551.932434  239.598572
# 18   37.591000  236.581680  551.493286  261.198547
# 19   36.529999  268.741638  552.655579  743.598572
#
#                                                  text  index  type
# 0   DISTRICT CANVASS\nPresidential General\n11/5/2...      0     0
# 1       PRINTED 11/15/24. 12:11 PM\nPAGE 001.002.01\n      1     0
# 2                          PUBLIC QUESTION QUESTION\n      2     0
# 20                                   STRAIGil PARTY\n     20     0
# 5                                                 1\n      5     0
# 7                                                 1\n      7     0
# 3                                                 1\n      3     0
# 8                                           1\nD\nL\n      8     0
# 4                                                 1\n      4     0
# 6                                                 1\n      6     0
# 9                                                 I\n      9     0
# 10                        1\n R V\nT P \n1\nE\nE\nB\n     10     0
# 11                   1\n E 0\nU E \n1\n1\n F>\nK\nE\n     11     0
# 12                         1\n ST\nR R \n1\nu\n0\nR\n     12     0
# 13        1\n I E\nB C\nN C \n1\n1\n B\nC\nT\nW T P\n     13     0
# 14        1\n S R\nA A\n0 E \n1\n1\n L\nR\nA\nE H E\n     14     0
# 15                  1\n T S\nL S\nU N\nI\nA\nR\nE 0\n     15     0
# 16               1\n E\nL T\nT T \n1\ny\nc\nT\nI\nP\n     16     0
# 17                        1\n0\nA\nE\nN\nA\nI\nA\nL\n     17     0
# 18  1\n E\nT\n6\n 1\nS\n0\n1\nC\nN\nE\n117 PRECINC...     18     0
# 19  0001 BAUGQ 1\n1\n 686\n452\n65.89 1\n211\n191\...     19     0

# %% [markdown]
# # Note to Self:
#
# Leaving this for later in case we can get a better PDF that is not a scanned copy.
